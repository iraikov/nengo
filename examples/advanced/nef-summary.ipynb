# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1821261477" href="javascript:toggle_input_1821261477()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1821261477;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1821261477 = document.getElementById("1821261477");
#                 var cell = link_1821261477;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1821261477;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1821261477 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1821261477 = cell.previousElementSibling;
#                 }
#                 input_1821261477.style.display = "none"; // hide
#
#                 toggle_input_1821261477 = function() {
#                     if (input_1821261477.style.display == "none") {
#                         input_1821261477.style.display = ""; // show
#                         link_1821261477.innerHTML = "Hide Input";
#                     } else {
#                         input_1821261477.style.display = "none"; // hide
#                         link_1821261477.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1821261477 = $("a[id='1821261477']");
#                 var cell_1821261477 = link_1821261477.parents("div.cell:first");
#                 if (cell_1821261477.length == 0) {
#                     cell_1821261477 = link_1821261477.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1821261477 = cell_1821261477.children("div.input");
#                 if (input_1821261477.length == 0) {
#                     input_1821261477 = cell_1821261477.prev("div.nbinput");
#                 }
#                 input_1821261477.hide();
#
#                 toggle_input_1821261477 = function() {
#                     if (input_1821261477.is(':hidden')) {
#                         input_1821261477.slideDown();
#                         link_1821261477[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1821261477.slideUp();
#                         link_1821261477[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="952249278" href="javascript:toggle_input_952249278()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_952249278;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_952249278 = document.getElementById("952249278");
#                 var cell = link_952249278;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_952249278;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_952249278 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_952249278 = cell.previousElementSibling;
#                 }
#                 input_952249278.style.display = "none"; // hide
#
#                 toggle_input_952249278 = function() {
#                     if (input_952249278.style.display == "none") {
#                         input_952249278.style.display = ""; // show
#                         link_952249278.innerHTML = "Hide Input";
#                     } else {
#                         input_952249278.style.display = "none"; // hide
#                         link_952249278.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_952249278 = $("a[id='952249278']");
#                 var cell_952249278 = link_952249278.parents("div.cell:first");
#                 if (cell_952249278.length == 0) {
#                     cell_952249278 = link_952249278.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_952249278 = cell_952249278.children("div.input");
#                 if (input_952249278.length == 0) {
#                     input_952249278 = cell_952249278.prev("div.nbinput");
#                 }
#                 input_952249278.hide();
#
#                 toggle_input_952249278 = function() {
#                     if (input_952249278.is(':hidden')) {
#                         input_952249278.slideDown();
#                         link_952249278[0].innerHTML = "Hide Input";
#                     } else {
#                         input_952249278.slideUp();
#                         link_952249278[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1815654244" href="javascript:toggle_input_1815654244()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1815654244;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1815654244 = document.getElementById("1815654244");
#                 var cell = link_1815654244;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1815654244;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1815654244 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1815654244 = cell.previousElementSibling;
#                 }
#                 input_1815654244.style.display = "none"; // hide
#
#                 toggle_input_1815654244 = function() {
#                     if (input_1815654244.style.display == "none") {
#                         input_1815654244.style.display = ""; // show
#                         link_1815654244.innerHTML = "Hide Input";
#                     } else {
#                         input_1815654244.style.display = "none"; // hide
#                         link_1815654244.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1815654244 = $("a[id='1815654244']");
#                 var cell_1815654244 = link_1815654244.parents("div.cell:first");
#                 if (cell_1815654244.length == 0) {
#                     cell_1815654244 = link_1815654244.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1815654244 = cell_1815654244.children("div.input");
#                 if (input_1815654244.length == 0) {
#                     input_1815654244 = cell_1815654244.prev("div.nbinput");
#                 }
#                 input_1815654244.hide();
#
#                 toggle_input_1815654244 = function() {
#                     if (input_1815654244.is(':hidden')) {
#                         input_1815654244.slideDown();
#                         link_1815654244[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1815654244.slideUp();
#                         link_1815654244[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="683559832" href="javascript:toggle_input_683559832()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_683559832;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_683559832 = document.getElementById("683559832");
#                 var cell = link_683559832;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_683559832;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_683559832 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_683559832 = cell.previousElementSibling;
#                 }
#                 input_683559832.style.display = "none"; // hide
#
#                 toggle_input_683559832 = function() {
#                     if (input_683559832.style.display == "none") {
#                         input_683559832.style.display = ""; // show
#                         link_683559832.innerHTML = "Hide Input";
#                     } else {
#                         input_683559832.style.display = "none"; // hide
#                         link_683559832.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_683559832 = $("a[id='683559832']");
#                 var cell_683559832 = link_683559832.parents("div.cell:first");
#                 if (cell_683559832.length == 0) {
#                     cell_683559832 = link_683559832.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_683559832 = cell_683559832.children("div.input");
#                 if (input_683559832.length == 0) {
#                     input_683559832 = cell_683559832.prev("div.nbinput");
#                 }
#                 input_683559832.hide();
#
#                 toggle_input_683559832 = function() {
#                     if (input_683559832.is(':hidden')) {
#                         input_683559832.slideDown();
#                         link_683559832[0].innerHTML = "Hide Input";
#                     } else {
#                         input_683559832.slideUp();
#                         link_683559832[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1858261125" href="javascript:toggle_input_1858261125()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1858261125;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1858261125 = document.getElementById("1858261125");
#                 var cell = link_1858261125;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1858261125;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1858261125 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1858261125 = cell.previousElementSibling;
#                 }
#                 input_1858261125.style.display = "none"; // hide
#
#                 toggle_input_1858261125 = function() {
#                     if (input_1858261125.style.display == "none") {
#                         input_1858261125.style.display = ""; // show
#                         link_1858261125.innerHTML = "Hide Input";
#                     } else {
#                         input_1858261125.style.display = "none"; // hide
#                         link_1858261125.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1858261125 = $("a[id='1858261125']");
#                 var cell_1858261125 = link_1858261125.parents("div.cell:first");
#                 if (cell_1858261125.length == 0) {
#                     cell_1858261125 = link_1858261125.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1858261125 = cell_1858261125.children("div.input");
#                 if (input_1858261125.length == 0) {
#                     input_1858261125 = cell_1858261125.prev("div.nbinput");
#                 }
#                 input_1858261125.hide();
#
#                 toggle_input_1858261125 = function() {
#                     if (input_1858261125.is(':hidden')) {
#                         input_1858261125.slideDown();
#                         link_1858261125[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1858261125.slideUp();
#                         link_1858261125[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="895981187" href="javascript:toggle_input_895981187()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_895981187;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_895981187 = document.getElementById("895981187");
#                 var cell = link_895981187;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_895981187;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_895981187 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_895981187 = cell.previousElementSibling;
#                 }
#                 input_895981187.style.display = "none"; // hide
#
#                 toggle_input_895981187 = function() {
#                     if (input_895981187.style.display == "none") {
#                         input_895981187.style.display = ""; // show
#                         link_895981187.innerHTML = "Hide Input";
#                     } else {
#                         input_895981187.style.display = "none"; // hide
#                         link_895981187.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_895981187 = $("a[id='895981187']");
#                 var cell_895981187 = link_895981187.parents("div.cell:first");
#                 if (cell_895981187.length == 0) {
#                     cell_895981187 = link_895981187.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_895981187 = cell_895981187.children("div.input");
#                 if (input_895981187.length == 0) {
#                     input_895981187 = cell_895981187.prev("div.nbinput");
#                 }
#                 input_895981187.hide();
#
#                 toggle_input_895981187 = function() {
#                     if (input_895981187.is(':hidden')) {
#                         input_895981187.slideDown();
#                         link_895981187[0].innerHTML = "Hide Input";
#                     } else {
#                         input_895981187.slideUp();
#                         link_895981187[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="453250832" href="javascript:toggle_input_453250832()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_453250832;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_453250832 = document.getElementById("453250832");
#                 var cell = link_453250832;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_453250832;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_453250832 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_453250832 = cell.previousElementSibling;
#                 }
#                 input_453250832.style.display = "none"; // hide
#
#                 toggle_input_453250832 = function() {
#                     if (input_453250832.style.display == "none") {
#                         input_453250832.style.display = ""; // show
#                         link_453250832.innerHTML = "Hide Input";
#                     } else {
#                         input_453250832.style.display = "none"; // hide
#                         link_453250832.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_453250832 = $("a[id='453250832']");
#                 var cell_453250832 = link_453250832.parents("div.cell:first");
#                 if (cell_453250832.length == 0) {
#                     cell_453250832 = link_453250832.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_453250832 = cell_453250832.children("div.input");
#                 if (input_453250832.length == 0) {
#                     input_453250832 = cell_453250832.prev("div.nbinput");
#                 }
#                 input_453250832.hide();
#
#                 toggle_input_453250832 = function() {
#                     if (input_453250832.is(':hidden')) {
#                         input_453250832.slideDown();
#                         link_453250832[0].innerHTML = "Hide Input";
#                     } else {
#                         input_453250832.slideUp();
#                         link_453250832[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1158627154" href="javascript:toggle_input_1158627154()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1158627154;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1158627154 = document.getElementById("1158627154");
#                 var cell = link_1158627154;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1158627154;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1158627154 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1158627154 = cell.previousElementSibling;
#                 }
#                 input_1158627154.style.display = "none"; // hide
#
#                 toggle_input_1158627154 = function() {
#                     if (input_1158627154.style.display == "none") {
#                         input_1158627154.style.display = ""; // show
#                         link_1158627154.innerHTML = "Hide Input";
#                     } else {
#                         input_1158627154.style.display = "none"; // hide
#                         link_1158627154.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1158627154 = $("a[id='1158627154']");
#                 var cell_1158627154 = link_1158627154.parents("div.cell:first");
#                 if (cell_1158627154.length == 0) {
#                     cell_1158627154 = link_1158627154.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1158627154 = cell_1158627154.children("div.input");
#                 if (input_1158627154.length == 0) {
#                     input_1158627154 = cell_1158627154.prev("div.nbinput");
#                 }
#                 input_1158627154.hide();
#
#                 toggle_input_1158627154 = function() {
#                     if (input_1158627154.is(':hidden')) {
#                         input_1158627154.slideDown();
#                         link_1158627154[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1158627154.slideUp();
#                         link_1158627154[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="676213418" href="javascript:toggle_input_676213418()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_676213418;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_676213418 = document.getElementById("676213418");
#                 var cell = link_676213418;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_676213418;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_676213418 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_676213418 = cell.previousElementSibling;
#                 }
#                 input_676213418.style.display = "none"; // hide
#
#                 toggle_input_676213418 = function() {
#                     if (input_676213418.style.display == "none") {
#                         input_676213418.style.display = ""; // show
#                         link_676213418.innerHTML = "Hide Input";
#                     } else {
#                         input_676213418.style.display = "none"; // hide
#                         link_676213418.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_676213418 = $("a[id='676213418']");
#                 var cell_676213418 = link_676213418.parents("div.cell:first");
#                 if (cell_676213418.length == 0) {
#                     cell_676213418 = link_676213418.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_676213418 = cell_676213418.children("div.input");
#                 if (input_676213418.length == 0) {
#                     input_676213418 = cell_676213418.prev("div.nbinput");
#                 }
#                 input_676213418.hide();
#
#                 toggle_input_676213418 = function() {
#                     if (input_676213418.is(':hidden')) {
#                         input_676213418.slideDown();
#                         link_676213418[0].innerHTML = "Hide Input";
#                     } else {
#                         input_676213418.slideUp();
#                         link_676213418[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1745158751" href="javascript:toggle_input_1745158751()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1745158751;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1745158751 = document.getElementById("1745158751");
#                 var cell = link_1745158751;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1745158751;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1745158751 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1745158751 = cell.previousElementSibling;
#                 }
#                 input_1745158751.style.display = "none"; // hide
#
#                 toggle_input_1745158751 = function() {
#                     if (input_1745158751.style.display == "none") {
#                         input_1745158751.style.display = ""; // show
#                         link_1745158751.innerHTML = "Hide Input";
#                     } else {
#                         input_1745158751.style.display = "none"; // hide
#                         link_1745158751.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1745158751 = $("a[id='1745158751']");
#                 var cell_1745158751 = link_1745158751.parents("div.cell:first");
#                 if (cell_1745158751.length == 0) {
#                     cell_1745158751 = link_1745158751.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1745158751 = cell_1745158751.children("div.input");
#                 if (input_1745158751.length == 0) {
#                     input_1745158751 = cell_1745158751.prev("div.nbinput");
#                 }
#                 input_1745158751.hide();
#
#                 toggle_input_1745158751 = function() {
#                     if (input_1745158751.is(':hidden')) {
#                         input_1745158751.slideDown();
#                         link_1745158751[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1745158751.slideUp();
#                         link_1745158751[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1635671309" href="javascript:toggle_input_1635671309()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1635671309;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1635671309 = document.getElementById("1635671309");
#                 var cell = link_1635671309;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1635671309;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1635671309 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1635671309 = cell.previousElementSibling;
#                 }
#                 input_1635671309.style.display = "none"; // hide
#
#                 toggle_input_1635671309 = function() {
#                     if (input_1635671309.style.display == "none") {
#                         input_1635671309.style.display = ""; // show
#                         link_1635671309.innerHTML = "Hide Input";
#                     } else {
#                         input_1635671309.style.display = "none"; // hide
#                         link_1635671309.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1635671309 = $("a[id='1635671309']");
#                 var cell_1635671309 = link_1635671309.parents("div.cell:first");
#                 if (cell_1635671309.length == 0) {
#                     cell_1635671309 = link_1635671309.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1635671309 = cell_1635671309.children("div.input");
#                 if (input_1635671309.length == 0) {
#                     input_1635671309 = cell_1635671309.prev("div.nbinput");
#                 }
#                 input_1635671309.hide();
#
#                 toggle_input_1635671309 = function() {
#                     if (input_1635671309.is(':hidden')) {
#                         input_1635671309.slideDown();
#                         link_1635671309[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1635671309.slideUp();
#                         link_1635671309[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1979591113" href="javascript:toggle_input_1979591113()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1979591113;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1979591113 = document.getElementById("1979591113");
#                 var cell = link_1979591113;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1979591113;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1979591113 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1979591113 = cell.previousElementSibling;
#                 }
#                 input_1979591113.style.display = "none"; // hide
#
#                 toggle_input_1979591113 = function() {
#                     if (input_1979591113.style.display == "none") {
#                         input_1979591113.style.display = ""; // show
#                         link_1979591113.innerHTML = "Hide Input";
#                     } else {
#                         input_1979591113.style.display = "none"; // hide
#                         link_1979591113.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1979591113 = $("a[id='1979591113']");
#                 var cell_1979591113 = link_1979591113.parents("div.cell:first");
#                 if (cell_1979591113.length == 0) {
#                     cell_1979591113 = link_1979591113.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1979591113 = cell_1979591113.children("div.input");
#                 if (input_1979591113.length == 0) {
#                     input_1979591113 = cell_1979591113.prev("div.nbinput");
#                 }
#                 input_1979591113.hide();
#
#                 toggle_input_1979591113 = function() {
#                     if (input_1979591113.is(':hidden')) {
#                         input_1979591113.slideDown();
#                         link_1979591113[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1979591113.slideUp();
#                         link_1979591113[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="558614416" href="javascript:toggle_input_558614416()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_558614416;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_558614416 = document.getElementById("558614416");
#                 var cell = link_558614416;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_558614416;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_558614416 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_558614416 = cell.previousElementSibling;
#                 }
#                 input_558614416.style.display = "none"; // hide
#
#                 toggle_input_558614416 = function() {
#                     if (input_558614416.style.display == "none") {
#                         input_558614416.style.display = ""; // show
#                         link_558614416.innerHTML = "Hide Input";
#                     } else {
#                         input_558614416.style.display = "none"; // hide
#                         link_558614416.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_558614416 = $("a[id='558614416']");
#                 var cell_558614416 = link_558614416.parents("div.cell:first");
#                 if (cell_558614416.length == 0) {
#                     cell_558614416 = link_558614416.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_558614416 = cell_558614416.children("div.input");
#                 if (input_558614416.length == 0) {
#                     input_558614416 = cell_558614416.prev("div.nbinput");
#                 }
#                 input_558614416.hide();
#
#                 toggle_input_558614416 = function() {
#                     if (input_558614416.is(':hidden')) {
#                         input_558614416.slideDown();
#                         link_558614416[0].innerHTML = "Hide Input";
#                     } else {
#                         input_558614416.slideUp();
#                         link_558614416[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
